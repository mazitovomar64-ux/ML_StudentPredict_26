# %%
import pandas as pd

# %% [markdown]
# ЭТАП 1: Анализ данных (EDA)
# Загрузка и базовая обработка

# %%
#1.	Загрузить датасет (из Kaggle или другого источника) и вывести первые 10 строк.
df = pd.read_csv('StudentsPerformance (2).csv')

# %%
df.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# 5                    none          71             83             78
# 6               completed          88             95             92
# 7                    none          40             43             39
# 8               completed          64             64             67
# 9                    none          38             60             50

# %%
#2.	Посмотреть .info(), .shape, .describe().
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.describe().round()
# Out:
#        math score  reading score  writing score
# count      1000.0         1000.0         1000.0
# mean         66.0           69.0           68.0
# std          15.0           15.0           15.0
# min           0.0           17.0           10.0
# 25%          57.0           59.0           58.0
# 50%          66.0           70.0           69.0
# 75%          77.0           79.0           79.0
# max         100.0          100.0          100.0

# %%
df.size
# Out:
# 8000

# %%
#3.	Вывести список колонок и их типы.
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
#4.	Проверить на пропущенные значения.
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df = df.rename(columns={'race/ethnicity': 'race_ethnicity', 'parental level of education': 'parental_level_of_education',
                   'test preparation course': 'test_preparation_course', 'math score': 'math_score',
                        'reading score': 'reading_score','writing score': 'writing_score'})

# %%
#5.	Сохранить очищенный датафрейм в students_clean.csv.
df.to_csv('students_clean.csv', sep=',', index=False)

# %%
df
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %%
df.columns
# Out:
# Index(['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course', 'math_score', 'reading_score',
#        'writing_score'],
#       dtype='object')

# %% [markdown]
# Pandas (20 задач)

# %%
#6.	Сколько уникальных значений у race/ethnicity?
df['race_ethnicity'].unique()
# Out:
# array(['group B', 'group C', 'group A', 'group D', 'group E'],
#       dtype=object)

# %%
count_race = df['race_ethnicity'].nunique()
print(f'Количество уникальных значений у race/ethnicity = {count_race}')
# Out:
# Количество уникальных значений у race/ethnicity = 5

# %%
#7.	Топ-3 самых высоких средних оценок по математике среди этнических групп.
df['math_score'].sort_values(ascending=False).head(3)
# Out:
# 451    100
# 458    100
# 962    100
# Name: math_score, dtype: int64

# %%
df.groupby('race_ethnicity')['math_score'].mean().round().sort_values(ascending=False).head(3)
# Out:
# race_ethnicity
# group E    74.0
# group D    67.0
# group C    64.0
# Name: math_score, dtype: float64

# %%
#8.	Сколько учеников прошли курс подготовки (test preparation course)?
count_completed = (df['test_preparation_course'] == 'completed').sum()
print(f'Количество учеников прошли курс подготовки = {count_completed}')
# Out:
# Количество учеников прошли курс подготовки = 358

# %%
df[df['test_preparation_course'] == 'completed']
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 1    female        group C                some college      standard
# 6    female        group B                some college      standard
# 8      male        group D                 high school  free/reduced
# 13     male        group A                some college      standard
# 18     male        group C             master's degree  free/reduced
# ..      ...            ...                         ...           ...
# 990    male        group E                 high school  free/reduced
# 991  female        group B            some high school      standard
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# 1                 completed          69             90             88
# 6                 completed          88             95             92
# 8                 completed          64             64             67
# 13                completed          78             72             70
# 18                completed          46             42             46
# ..                      ...         ...            ...            ...
# 990               completed          86             81             75
# 991               completed          65             82             78
# 995               completed          88             99             95
# 997               completed          59             71             65
# 998               completed          68             78             77
#
# [358 rows x 8 columns]

# %%
#9.	Средняя оценка по математике среди тех, кто прошел курс.
df.groupby('test_preparation_course')['math_score'].mean().round()
# Out:
# test_preparation_course
# completed    70.0
# none         64.0
# Name: math_score, dtype: float64

# %%
count = df[df['test_preparation_course'] == 'completed']['math_score'].mean().round()
print(f'Средняя оценка по математике среди тех, кто прошел курс = {count}')
# Out:
# Средняя оценка по математике среди тех, кто прошел курс = 70.0

# %%
#10.	Средняя оценка по чтению среди учеников с бесплатным питанием (lunch == free/reduced).
count_free = df[df['lunch'] == 'free/reduced']['reading_score'].mean().round()
print(f'Средняя оценка по чтению среди учеников с бесплатным питанием = {count_free}')
# Out:
# Средняя оценка по чтению среди учеников с бесплатным питанием = 65.0

# %%
df.groupby('lunch')['reading_score'].mean().round()
# Out:
# lunch
# free/reduced    65.0
# standard        72.0
# Name: reading_score, dtype: float64

# %%
#11.	Сколько учеников с уровнем образования родителей bachelor's degree?
(df['parental_level_of_education'] == "bachelor's degree").sum()
# Out:
# np.int64(118)

# %%
#12.	Средние баллы по всем предметам по полу (gender).
df.groupby('gender') ['math_score'].mean().round()
# Out:
# gender
# female    64.0
# male      69.0
# Name: math_score, dtype: float64

# %%
df.groupby('gender') ['reading_score'].mean().round()
# Out:
# gender
# female    73.0
# male      65.0
# Name: reading_score, dtype: float64

# %%
df.groupby('gender') ['writing_score'].mean().round()
# Out:
# gender
# female    72.0
# male      63.0
# Name: writing_score, dtype: float64

# %%
df.groupby('gender') [['math_score', 'writing_score', 'reading_score']].mean().round()
# Out:
#         math_score  writing_score  reading_score
# gender
# female        64.0           72.0           73.0
# male          69.0           63.0           65.0

# %%
#13.	У кого медианная оценка по письму выше — мужчины или женщины?
df.groupby('gender') ['writing_score'].median().round()
# Out:
# gender
# female    74.0
# male      64.0
# Name: writing_score, dtype: float64

# %%
#14.	Средний балл по математике по уровню образования родителей.
df.groupby('parental_level_of_education') ['math_score'].mean().round().sort_values(ascending=False)
# Out:
# parental_level_of_education
# master's degree       70.0
# bachelor's degree     69.0
# associate's degree    68.0
# some college          67.0
# some high school      63.0
# high school           62.0
# Name: math_score, dtype: float64

# %%
#15.	Группировка по test preparation course и lunch + средние оценки.
df.groupby(['test_preparation_course','lunch'])[['math_score', 'writing_score', 'reading_score']].mean().round()
# Out:
#                                       math_score  writing_score  reading_score
# test_preparation_course lunch
# completed               free/reduced        63.0           70.0           70.0
#                         standard            74.0           77.0           76.0
# none                    free/reduced        57.0           59.0           62.0
#                         standard            68.0           68.0           69.0

# %%
#16.	Найти самого успешного ученика (максимум по сумме 3 оценок).
df['all_score'] = df['math_score'] +  df['reading_score'] + df['reading_score']

# %%
df['all_score'].max()
# Out:
# 300

# %%
(df['all_score'] == 300).sum()
# Out:
# np.int64(4)

# %%
df[df['all_score'] == 300]
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 458  female        group E           bachelor's degree      standard
# 916    male        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
#
#     test_preparation_course  math_score  reading_score  writing_score  \
# 149               completed         100            100             93
# 458                    none         100            100            100
# 916               completed         100            100            100
# 962                    none         100            100            100
#
#      all_score
# 149        300
# 458        300
# 916        300
# 962        300

# %%
#17.	У скольких учеников math score >= 90?
(df['math_score'] >= 90).sum()
# Out:
# np.int64(58)

# %%
#18.	У скольких учеников все три оценки больше 80?
((df['math_score'] > 80) & (df['reading_score'] > 80) & (df['writing_score'] > 80)).sum()
# Out:
# np.int64(110)

# %%
#19.	Группировка по gender, race/ethnicity, mean().
df.groupby(['gender', 'race_ethnicity'])[['math_score', 'writing_score', 'reading_score']].mean().round()
# Out:
#                        math_score  writing_score  reading_score
# gender race_ethnicity
# female group A               59.0           68.0           69.0
#        group B               61.0           70.0           71.0
#        group C               62.0           72.0           72.0
#        group D               65.0           75.0           74.0
#        group E               71.0           76.0           76.0
# male   group A               64.0           59.0           62.0
#        group B               66.0           60.0           63.0
#        group C               68.0           63.0           65.0
#        group D               69.0           65.0           66.0
#        group E               77.0           67.0           70.0

# %%
#20.	Создать новый столбец average_score = среднее из трех оценок.
df['average_score'] = round(df['all_score'] / 3)
# print(f'Среднея оценка из трех оценок = {avg_count}')

# %%
df
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      all_score  average_score
# 0          216           72.0
# 1          249           83.0
# 2          280           93.0
# 3          161           54.0
# 4          232           77.0
# ..         ...            ...
# 995        286           95.0
# 996        172           57.0
# 997        201           67.0
# 998        224           75.0
# 999        249           83.0
#
# [1000 rows x 10 columns]
